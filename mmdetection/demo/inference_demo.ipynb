# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv
import matplotlib.pyplot as plt

# %%
config_file = '/home/badboy-002/github/senior_project/mmdetection/configs/cascade_rcnn/bacteria_cascade_r50.py'
# download the checkpoint from model zoo and put it in `checkpoints/`
# url: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
checkpoint_file = '/home/badboy-002/github/senior_project/mmdetection/work_dirs/bacteria_cascade_r50_3-10-22/epoch_400.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')
# Out:
# load checkpoint from local path: /home/badboy-002/github/senior_project/mmdetection/work_dirs/bacteria_cascade_r50_3-10-22/epoch_400.pth

# %%
import cv2
amp = cv2.imread('/home/badboy-002/github/senior_project/rgb_bacteria/Bacteria images/Ampicillin/RGB/20220819_TS008_1hr_1mindye_AMP_1X_01_R3D_D3D_CRC-1.tif (RGB).tif')
gray = cv2.cvtColor(amp,cv2.COLOR_BGR2GRAY)
filename = '/home/badboy-002/github/senior_project/rgb_bacteria/Bacteria images/Ampicillin/gray_amp.png'
cv2.imwrite(filename, gray)
# Out:
# True

# %%
original = cv2.imread('/home/badboy-002/github/senior_project/Bacteria_png/Ampicillin/20220819_TS008_1hr_1mindye_AMP_1X_01_R3D_D3D_CRC-1.png')

# %%
# test a single image
img = original
result = inference_detector(model, img)
# Out:
# /home/badboy-002/github/senior_project/mmdetection/mmdet/datasets/utils.py:66: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   warnings.warn(

# %%
# show the results
plt.imshow(gray, cmap = 'gray')

show_result_pyplot(model, img, result)
