# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from PIL import Image
import requests
from pycocotools.coco import COCO

# %%
import json

# %%
with open("/home/badboy-002/github/senior_project/web-app/backend/response_1681057417761.json", "r") as js:
    data = json.load(js)
    print(len(data['image']))
# Out:
# 2

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    [[1,2,3,4],
      [5,6,7,8]]
)

# %%
isinstance(df, pd.DataFrame)
# Out:
# True

# %%
for model in
# Out:
# {'config': 'value1.1', 'check_point': 'value1.2'}
# config:  config
# check point:  value1.1
# config:  check_point
# check point:  value1.2
# {'config': 'value2.1', 'check_point': 'value2.2'}
# config:  config
# check point:  value2.1
# config:  check_point
# check point:  value2.2

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("output.png")
plt.imshow(img*255)
